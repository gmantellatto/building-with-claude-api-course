# %%
# Create an API client and Helper Functions
from anthropic import Anthropic
from dotenv import load_dotenv
import os

load_dotenv()

token = os.environ["ANTHROPIC_AUTH_TOKEN"]
url = os.environ["ANTHROPIC_BASE_URL"]
model = os.environ["ANTHROPIC_MODEL"]

client = Anthropic(
    api_key=token,
    base_url=url,
    default_headers={"Authorization": f"Bearer {token}"}
)

def add_user_message(messages, content):
    user_message = { "role": "user", "content": content }
    messages.append(user_message)

def add_assistant_message(messages, content):
    assistant_message = { "role": "assistant", "content": content }
    messages.append(assistant_message)

def chat(messages, system=None):

  params = {
    "model": model,
    "max_tokens": 1000,
    "messages": messages,
  }

  if system:
    params["system"] = system
  
  message = client.messages.create(**params)
  return message.content[0].text

# %%
messages = []

add_user_message(
  messages, 
  "Write a python function that checks a string for duplicate characters.",
)

answer = chat(messages)
print(answer)
# Out:
# ## Check for Duplicate Characters in a String
#
# Here's a Python function that checks a string for duplicate characters:
#
# ```python
# def check_duplicates(string: str) -> dict:
#     """
#     Checks a string for duplicate characters.
#
#     Args:
#         string: The input string to check.
#
#     Returns:
#         A dictionary containing:
#             - 'has_duplicates': bool indicating if duplicates exist
#             - 'duplicates': dict of duplicate characters and their counts
#     """
#     char_count = {}
#
#     for char in string:
#         char_count[char] = char_count.get(char, 0) + 1
#
#     duplicates = {char: count for char, count in char_count.items() if count > 1}
#
#     return {
#         "has_duplicates": len(duplicates) > 0,
#         "duplicates": duplicates
#     }
#
#
# # Example usage
# if __name__ == "__main__":
#     test_strings = [
#         "hello",
#         "world",
#         "python",
#         "abcdefg",
#         "mississippi"
#     ]
#
#     for string in test_strings:
#         result = check_duplicates(string)
#         print(f"String: '{string}'")
#         print(f"  Has duplicates: {result['has_duplicates']}")
#         if result['has_duplicates']:
#             print(f"  Duplicate characters: {result['duplicates']}")
#         print()
# ```
#
# ### Output
#
# ```
# String: 'hello'
#   Has duplicates: True
#   Duplicate characters: {'l': 2}
#
# String: 'world'
#   Has duplicates: False
#
# String: 'python'
#   Has duplicates: False
#
# String: 'abcdefg'
#   Has duplicates: False
#
# String: 'mississippi'
#   Has duplicates: True
#   Duplicate characters: {'s': 4, 'i': 4, 'p': 2}
# ```
#
# ### Alternative Approaches
#
# **Using `collections.Counter`** (more concise):
# ```python
# from collections import Counter
#
# def check_duplicates_counter(string: str) -> dict:
#     char_count = Counter(string)
#     duplicates = {char: count for char, count in char_count.items() if count > 1}
#     return {
#         "has_duplicates": len(duplicates) > 0,
#         "duplicates": duplicates
#     }
# ```
#
# **Simple boolean check** (just returns `True`/`False`):
# ```python
# def has_duplicates(string: str) -> bool:
#     return len(string) != len(set(string))
# ```
#
# ### Key Notes
# | Approach | Use Case | Time Complexity |
# |---|---|---|
# | `dict` counting | When you need character counts | O(n) |
# | `collections.Counter` | Cleaner syntax, same result | O(n) |
# | `set` comparison | Just need a `True`/`False` answer | O(n) |
#
# The `set` approach is the **most efficient** for a simple duplicate check, while the `Counter` approach is best when you need **detailed information** about duplicates.

# %%
messages = []

add_user_message(
  messages, 
  "Write a python function that checks a string for duplicate characters.",
)

system_prompt = """
You are an experienced python developer.
Your response should be as concise and direct as possible, with just the code when it fits.
Return only what was asked for, and nothing else.
"""

answer = chat(messages, system_prompt)
print(answer)
# Out:
# ```python
# def has_duplicate_characters(s: str) -> bool:
#     return len(s) != len(set(s))
# ```
